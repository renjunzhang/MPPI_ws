# %% [markdown]
# 启动世界步骤

# %%
source /data/a/MPPI_ws/devel/setup.bash      # 按你自己的工作空间改
# 第一步
roslaunch ridgeback_gazebo ridgeback_world.launch gui:=false headless:=true

# 第二步
gzclient
# 或 rosrun gazebo_ros gzclient

# 第三步
roslaunch ridgeback_navigation ridgeback_description.launch

# 第四步 启动遥控节点
roslaunch ridgeback_navigation teleop.launch

# %% [markdown]
# # 但是现在的rviz的Fixed Frame是odom，因为还没有启动mapserver和amcl
#
# # 接下来先启动mapserver然后有地图，但是定位不对
# rosrun map_server map_server /data/a/MPPI_ws/src/ridgeback_navigation/maps/ridgeback_map.yaml
#
# # 启动amcl进行定位
# rosrun amcl amcl scan:=/front/scan

# %% [markdown]
# source /data/a/MPPI_ws/devel/setup.bash      # 按你自己的工作空间改
# # 最后启动move_base导航服务
# roslaunch ridgeback_navigation move_base.launch
